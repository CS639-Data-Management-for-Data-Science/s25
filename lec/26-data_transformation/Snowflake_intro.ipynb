# %%
import snowflake.connector
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Read Snowflake password
with open("snowflake_password", "r") as file:
    snowflake_password = file.read()
    snowflake_password = snowflake_password.strip()

# %%
# Connect to Snowflake
conn = snowflake.connector.connect(
    user='MSYAMKUMAR25', # Snowflake username
    password=snowflake_password, # Snowflake password
    account='SY56707.us-central1.gcp' # <account_name>.<region>.<cloud_provider>
)

# Create cursor object instance
cursor = conn.cursor()

# %%
cursor.execute("USE DATABASE AIRBYTE_DATABASE;")
cursor.execute("USE SCHEMA AIRBYTE_SCHEMA;")

df = pd.read_sql("""
SELECT * 
FROM SURVEY
""", conn)
df
# Out:
# /tmp/ipykernel_345906/2080036561.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""
#                          _AIRBYTE_RAW_ID            _AIRBYTE_EXTRACTED_AT  \
# 0   74d7bebe-1b80-4eb7-bb80-65c1b21305e4 2025-03-21 16:10:35.169000+00:00
# 1   51052f23-8be0-4166-99ce-e5eca79b8cde 2025-03-21 16:10:35.169000+00:00
# 2   45c9a955-e218-41eb-9246-ed4181d0b236 2025-03-21 16:10:35.169000+00:00
# 3   6e76214f-09de-49d3-a374-abc1bce224c6 2025-03-21 16:10:35.169000+00:00
# 4   ec575256-554b-4c0a-99d4-a0012f11e0a6 2025-03-21 16:10:35.174000+00:00
# 5   86e742ca-ac59-4265-a5cc-c320622af6ba 2025-03-21 16:10:35.170000+00:00
# 6   152429f6-2096-4459-8735-ab550b0678ce 2025-03-21 16:10:35.170000+00:00
# 7   35002db3-2bd9-45c4-88f2-321b6d8b2ea2 2025-03-21 16:10:35.170000+00:00
# ...

# %%
df = pd.read_sql("""
SELECT * FROM AIRBYTE_SCHEMA.transform_survey
LIMIT 10;
""", conn)
df
# Out:
# /tmp/ipykernel_345906/3245770031.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""
#           SURVEY_TIME                EMAIL AGE     PRIMARY_MAJOR  \
# 0  3/19/2025 13:29:38   igallucci@wisc.edu  22      Data Science
# 1  3/19/2025 13:29:54   jwcramer2@wisc.edu  21      Data Science
# 2  3/19/2025 13:30:35  jzhang2752@wisc.edu  20      Data Science
# 3  3/19/2025 13:29:05   entackett@wisc.edu  20  Mathematics/AMEP
# 4  3/20/2025 16:01:25    amohan33@wisc.edu  21  Computer Science
# 5  3/19/2025 13:30:37      mkuo22@wisc.edu  19      Data Science
# 6  3/19/2025 13:30:36    tliang34@wisc.edu  23      Data Science
# 7  3/19/2025 13:30:45    dsmith73@wisc.edu  21      Data Science
# 8  3/19/2025 16:53:50     tpnagar@wisc.edu  22  Computer Science
# ...

# %%
conn.close()
