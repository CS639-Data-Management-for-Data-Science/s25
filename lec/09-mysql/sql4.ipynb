# %% [markdown]
# ## SQL 3: Subqueries and joins

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import os
import gc

# %%
engine = create_engine("mysql+mysqlconnector://root:abc@127.0.0.1:3306/cs639")
conn = engine.connect()

# %%
list(conn.execute(text("show tables;")))
# Out:
# [('name_basics',),
#  ('title_akas',),
#  ('title_basics',),
#  ('title_crew',),
#  ('title_episode',),
#  ('title_principals',),
#  ('title_ratings',)]

# %% [markdown]
# ### IMDB dataset
#
# - Source: https://datasets.imdbws.com/
# - Original dataset is too large to be analyzed using our current VM
# - Schema information: https://developer.imdb.com/non-commercial-datasets/

# %%
# !rm IMDB.zip
# !rm *.tsv
# !wget https://ms.sites.cs.wisc.edu/cs639/data/IMDB.zip
# !unzip IMDB.zip
# Out:
# rm: cannot remove 'IMDB.zip': No such file or directory
# rm: cannot remove '*.tsv': No such file or directory
# --2025-02-10 18:54:49--  https://ms.sites.cs.wisc.edu/cs639/data/IMDB.zip
# 65.8.243.101, 65.8.243.112, 65.8.243.63, ...wisc.edu)...
# connected. to ms.sites.cs.wisc.edu (ms.sites.cs.wisc.edu)|65.8.243.101|:443...
# 200 OKequest sent, awaiting response...
# Length: 584293 (571K) [application/zip]
# Saving to: ‘IMDB.zip’
#
# IMDB.zip            100%[===================>] 570.60K  2.87MB/s    in 0.2s
#
# 2025-02-10 18:54:50 (2.87 MB/s) - ‘IMDB.zip’ saved [584293/584293]
#
# Archive:  IMDB.zip
#   inflating: name.basics.tsv
#   inflating: title.akas.tsv
#   inflating: title.basics.tsv
#   inflating: title.crew.tsv
#   inflating: title.episode.tsv
#   inflating: title.principals.tsv
#   inflating: title.ratings.tsv

# %% [markdown]
# #### Populating MySQL server with tables corresponding to all tsv files

# %%
files = os.listdir()
tsv_files = [f for f in files if ".tsv" in f]
table_names = [f.replace(".tsv", "") for f in tsv_files]
table_names = [f.replace(".", "_") for f in table_names]

# %%
for idx, tsv_file in enumerate(tsv_files):
    df = pd.read_csv(tsv_file, sep="\t", na_values='\\N')
    df.to_sql(table_names[idx], conn, index=False, if_exists="replace")
    print(f"Populated {table_names[idx]}")
# Out:
# Populated title_basics
# Populated title_principals
# Populated title_akas
# Populated name_basics
# Populated title_episode
# Populated title_ratings
# Populated title_crew

# %%
list(conn.execute(text("show tables;")))
# Out:
# [('name_basics',),
#  ('title_akas',),
#  ('title_basics',),
#  ('title_crew',),
#  ('title_episode',),
#  ('title_principals',),
#  ('title_ratings',)]

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# ### SQL Subqueries
#
# - What is a subquery?
#     - A query contained within another query. The outer query is typically referred to as "containing statement".
#     - A subquery can be used with all four SQL data statements: `SELECT`, `INSERT`, `UPDATE`, `DELETE`.
#     - The subquery is always executed prior to the containing statement.
#     - Subqueries act like a temporary table with statement scope. That is when the containing statement has finished executing, data returned by the subqueries are discarded.
#     - Subqueries can return:
#         - Single row with a single column
#         - Multiple rows with a single column
#         - Multiple rows with multiple columns
# - Types of subqueries:
#     1. noncorrelated subqueries: self-contained subqueries
#     2. correlated subqueries: reference columns from the containing statement

# %% [markdown]
# ### Noncorrelated subqueries
#
# - What is a scalar subquery?
#     - A query returning a result set containing a single row and column.
#     - Can be used for conditional operators: `=`, `<`, `<=`, `>`, `>=`, `<>`

# %% [markdown]
# #### Single-Row and Single-Column subqueries

# %% [markdown]
# #### Q1: What are the titles that have a runtime greater than the average runtime of all movies?

# %%
pd.read_sql("""
    SELECT AVG(runtimeMinutes)
    FROM title_basics
    WHERE runtimeMinutes IS NOT NULL
""", conn)
# Out:
#    AVG(runtimeMinutes)
# 0            42.008753

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    WHERE runtimeMinutes > (
        SELECT AVG(runtimeMinutes)
        FROM title_basics
        WHERE runtimeMinutes IS NOT NULL
)
""", conn)
# Out:
#         tconst  titleType         primaryTitle        originalTitle  isAdult  \
# 0    tt0017504      movie       Unseen Enemies       Unseen Enemies        0
# 1    tt0024996      movie     Coming Out Party     Coming Out Party        0
# 2    tt0029553      movie  The Sheik Steps Out  The Sheik Steps Out        0
# 3    tt0035860      movie   The Fallen Sparrow   The Fallen Sparrow        0
# 4    tt0037142      movie    Oath of Vengeance    Oath of Vengeance        0
# ..         ...        ...                  ...                  ...      ...
# 355  tt9653828      movie                Arest                Arest        0
# 356  tt9654270   tvSeries   Giardino d'inverno   Giardino d'inverno        0
# 357  tt9685774    tvMovie   The Farewell Girls   The Farewell Girls        0
# 358  tt9728774   tvSeries   Innocent the Bhola   Innocent the Bhola        0
# 359  tt9796264  tvEpisode        Alt for Noreg        Alt for Noreg        0
#
#      startYear  endYear  runtimeMinutes             genres
# 0       1925.0      NaN            54.0            Western
# 1       1934.0      NaN            80.0              Drama
# 2       1937.0      NaN            65.0            Musical
# 3       1943.0      NaN            94.0  Film-Noir,Mystery
# 4       1944.0      NaN            57.0            Western
# ..         ...      ...             ...                ...
# 355     2019.0      NaN           126.0              Drama
# 356     1961.0   1961.0           120.0             Comedy
# 357     2017.0      NaN            86.0              Drama
# 358     2020.0      NaN            98.0           Thriller
# 359     2019.0      NaN            45.0        Drama,Sport
#
# [360 rows x 9 columns]

# %% [markdown]
# #### Q2: What are the most recent movies?

# %%
pd.read_sql("""
    SELECT MAX(startYear)
    FROM title_basics
    WHERE titleType = 'movie'
""", conn)
# Out:
#    MAX(startYear)
# 0          2024.0

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    WHERE startYear = (
        SELECT MAX(startYear)
        FROM title_basics
        WHERE titleType = 'movie'
    ) AND titleType = 'movie'
""", conn)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0  tt16311360     movie                              Krzyk: Losing Control
# 1  tt29009061     movie                                     Amici per caso
# 2  tt32848875     movie  Dad and I - Chapter 1: The Life of Timothy J. ...
#
#                                        originalTitle  isAdult  startYear  \
# 0                              Krzyk: Losing Control        0     2024.0
# 1                                     Amici per caso        0     2024.0
# 2  Dad and I - Chapter 1: The Life of Timothy J. ...        0     2024.0
#
#   endYear  runtimeMinutes          genres
# 0    None            80.0  Drama,Thriller
# 1    None            95.0          Comedy
# 2    None           111.0       Biography

# %% [markdown]
# #### Multiple-Row and Single-Column subqueries
#
# - Operators: `IN`, `NOT IN`, `ALL`, `ANY`

# %% [markdown]
# #### Q3: Find the number of movies that have more than one genre.

# %% [markdown]
# We can find number of genres by simply counting number of commas and adding 1 to that count. Let's first determine length of genres column.

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    LIMIT 5
""", conn)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0000912     short  The Indian Runner's Romance
# 1  tt0013001     short                  The Cashier
# 2  tt0016344     movie          Shirayuri wa nageku
# 3  tt0017504     movie               Unseen Enemies
# 4  tt0024996     movie             Coming Out Party
#
#                  originalTitle  isAdult  startYear endYear  runtimeMinutes  \
# 0  The Indian Runner's Romance        0     1909.0    None            11.0
# 1                  The Cashier        0     1922.0    None             NaN
# 2          Shirayuri wa nageku        0     1925.0    None             NaN
# 3               Unseen Enemies        0     1925.0    None            54.0
# 4             Coming Out Party        0     1934.0    None            80.0
#
#                    genres
# 0           Short,Western
# 1  Animation,Comedy,Short
# 2                    None
# 3                 Western
# 4                   Drama

# %% [markdown]
# `LENGTH` in SQL.

# %%
pd.read_sql("""
    SELECT genres, LENGTH(genres)
    FROM title_basics
""", conn)
# Out:
#                       genres  LENGTH(genres)
# 0              Short,Western            13.0
# 1     Animation,Comedy,Short            22.0
# 2                       None             NaN
# 3                    Western             7.0
# 4                      Drama             5.0
# ...                      ...             ...
# 2769                   Drama             5.0
# 2770            Family,Short            12.0
# 2771               Game-Show             9.0
# 2772                  Comedy             6.0
# 2773             Documentary            11.0
#
# [2774 rows x 2 columns]

# %% [markdown]
# To find, number of commas, we can replace commas with nothing and find difference between original string and the replaced string.

# %%
pd.read_sql("""
    SELECT genres, LENGTH(genres) - LENGTH(REPLACE(genres, ',', '')) + 1
    FROM title_basics
""", conn)
# Out:
#                       genres  \
# 0              Short,Western
# 1     Animation,Comedy,Short
# 2                       None
# 3                    Western
# 4                      Drama
# ...                      ...
# 2769                   Drama
# 2770            Family,Short
# 2771               Game-Show
# 2772                  Comedy
# 2773             Documentary
#
#       LENGTH(genres) - LENGTH(REPLACE(genres, ',', '')) + 1
# 0                                                   2.0
# 1                                                   3.0
# 2                                                   NaN
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 2769                                                1.0
# 2770                                                2.0
# 2771                                                1.0
# 2772                                                1.0
# 2773                                                1.0
#
# [2774 rows x 2 columns]

# %% [markdown]
# Now putting it together in a subquery.

# %%
pd.read_sql("""
    SELECT COUNT(*)
    FROM title_basics
    WHERE (
        SELECT LENGTH(genres) - LENGTH(REPLACE(genres, ',', '')) + 1
    ) > 1;
""", conn)
# Out:
#    COUNT(*)
# 0      1181

# %% [markdown]
# #### Q4: Find the titles of movies that have the maximum number of genres.

# %%
pd.read_sql("""
    SELECT primaryTitle, genres
    FROM title_basics
    WHERE (
        SELECT LENGTH(genres) - LENGTH(REPLACE(genres, ',', '')) + 1
    ) = (
        SELECT MAX(LENGTH(genres) - LENGTH(REPLACE(genres, ',', '')) + 1)
        FROM title_basics
    )
""", conn)
# Out:
#                       primaryTitle                      genres
# 0                      The Cashier      Animation,Comedy,Short
# 1                You Bet Your Life     Comedy,Family,Game-Show
# 2              Return of the Seven        Action,Drama,Western
# 3                       Kindergeld         Crime,Drama,Mystery
# 4                         Mindwarp      Horror,Sci-Fi,Thriller
# ..                             ...                         ...
# 442  Episode dated 21 January 2019  Documentary,News,Talk-Show
# 443  Episode dated 5 November 2018  Documentary,News,Talk-Show
# 444              Frozen and Afraid  Adventure,Game-Show,Horror
# 445                  Múmia do Amor  Adventure,Animation,Comedy
# 446                 Episode #1.372          Action,Crime,Drama
#
# [447 rows x 2 columns]

# %% [markdown]
# #### Q5: Find the titles of movies that belong to the same genres as those with a runtime longer than 150 minutes.

# %%
pd.read_sql("""
    SELECT genres
    FROM title_basics
    WHERE titleType = "movie" AND runtimeMinutes > 150 AND genres IS NOT NULL
""", conn)
# Out:
#   genres
# 0  Drama

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    WHERE genres IN (
        SELECT genres
        FROM title_basics
        WHERE titleType = "movie" AND runtimeMinutes > 150 AND genres IS NOT NULL
    ) AND titleType = "movie"
""", conn)
# Out:
#         tconst titleType                            primaryTitle  \
# 0    tt0024996     movie                        Coming Out Party
# 1    tt0098516     movie          Trois pommes à côté du sommeil
# 2    tt0173156     movie                          Saajan Ka Ghar
# 3    tt0179070     movie                   All the King's Horses
# 4    tt0228992     movie                       An Outgoing Woman
# 5    tt0268446     movie                          Mask of Desire
# 6    tt0328672     movie             A Yellow Raft in Blue Water
# 7    tt0347010     movie                              Fondovalle
# 8    tt0349688     movie                 A Little Bit of Freedom
# 9    tt0371002     movie                   Ne se sardi, choveche
# 10   tt0380699     movie                                  Selosa
# 11   tt0430891     movie                                    Aria
# 12   tt0463992     movie  Finish Line: A Cruise Down Memory Lane
# 13  tt13284100     movie                      Shirdi Sri Saibaba
# 14   tt1419916     movie            Chowrasta Crossroads of Love
# 15  tt21058618     movie                     18. The Book of Job
# 16   tt2174658     movie                  Yi ge wen ti xue sheng
# 17  tt21963824     movie                            Diamond Four
# 18  tt22989270     movie                        Great Depression
# 19  tt31868404     movie                             Mother Lear
# 20   tt3248938     movie                             Irish Story
# 21   tt3662778     movie                               Americana
# 22   tt5822612     movie                                   Re ye
# 23   tt6971664     movie                     Elzának Szeretettel
# 24   tt7964296     movie                        Jidai no hankôji
# 25   tt9653828     movie                                   Arest
#
#                              originalTitle  isAdult  startYear endYear  \
# 0                         Coming Out Party        0     1934.0    None
# 1           Trois pommes à côté du sommeil        0     1989.0    None
# 2                           Saajan Ka Ghar        0     1994.0    None
# 3                    All the King's Horses        0     1977.0    None
# 4                    Une femme d'extérieur        0     2000.0    None
# 5                                  Mukundo        0     2000.0    None
# 6              A Yellow Raft in Blue Water        0        NaN    None
# 7                               Fondovalle        0     1998.0    None
# 8                          Kleine Freiheit        0     2003.0    None
# 9                    Ne se sardi, choveche        0     1985.0    None
# 10                                  Selosa        0     1997.0    None
# 11                                    Aria        0     2004.0    None
# 12  Finish Line: A Cruise Down Memory Lane        0     2005.0    None
# 13                      Shirdi Sri Saibaba        0     2015.0    None
# 14            Chowrasta Crossroads of Love        0     2009.0    None
# 15                     18. The Book of Job        0        NaN    None
# 16                  Yi ge wen ti xue sheng        0     1980.0    None
# 17                            Diamond Four        0        NaN    None
# 18                        Great Depression        0     2022.0    None
# 19                             Mother Lear        0     2023.0    None
# 20                                  Legend        0        NaN    None
# 21                               Americana        0     2016.0    None
# 22                                   Re ye        0     1976.0    None
# 23                     Elzának Szeretettel        0        NaN    None
# 24                        Jidai no hankôji        0     1930.0    None
# 25                                   Arest        0     2019.0    None
#
#     runtimeMinutes genres
# 0             80.0  Drama
# 1             98.0  Drama
# 2            153.0  Drama
# 3             80.0  Drama
# 4            118.0  Drama
# 5            105.0  Drama
# 6              NaN  Drama
# 7             74.0  Drama
# 8            102.0  Drama
# 9             81.0  Drama
# 10             NaN  Drama
# 11            57.0  Drama
# 12             NaN  Drama
# 13            90.0  Drama
# 14           120.0  Drama
# 15             NaN  Drama
# 16             NaN  Drama
# 17             NaN  Drama
# 18           120.0  Drama
# 19            57.0  Drama
# 20             NaN  Drama
# 21            81.0  Drama
# 22             NaN  Drama
# 23             NaN  Drama
# 24             NaN  Drama
# 25           126.0  Drama

# %% [markdown]
# #### Q6: Find titles of movies that have not received any ratings.

# %%
pd.read_sql("SELECT tconst FROM title_ratings", conn)
# Out:
#         tconst
# 0    tt0000912
# 1    tt0017504
# 2    tt0024996
# 3    tt0029553
# 4    tt0030476
# ..         ...
# 384  tt9728774
# 385  tt9758424
# 386  tt9796264
# 387  tt9847426
# 388  tt9854186
#
# [389 rows x 1 columns]

# %%
pd.read_sql("""
    SELECT primaryTitle
    FROM title_basics
    WHERE titleType = 'movie' 
    AND tconst NOT IN (
        SELECT tconst
        FROM title_ratings
)
""", conn)
# Out:
#                       primaryTitle
# 0              Shirayuri wa nageku
# 1                      L'ippocampo
# 2                Diary of a Window
# 3                Der Elfenbeinturm
# 4                        Zhi Mo Nu
# ..                             ...
# 88                       Dreamlock
# 89                Making Masculine
# 90                            Gado
# 91  A Song or Two to Make You Feel
# 92                My Hero Academia
#
# [93 rows x 1 columns]

# %% [markdown]
# #### Q7: Find all the titles that have an average rating greater than all titles released in the year 2005.

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    WHERE tconst IN (
        SELECT tconst
        FROM title_ratings
        WHERE averageRating > ALL (
            SELECT averageRating
            FROM title_ratings
            WHERE tconst IN (
                SELECT tconst
                FROM title_basics
                WHERE startYear = 2005
            )
        )
    )
""", conn)
# Out:
#         tconst  titleType                 primaryTitle  \
# 0    tt0042171   tvSeries            You Bet Your Life
# 1    tt0108382      short           The Traveling Poet
# 2    tt0118989    tvMovie  The Ditchdigger's Daughters
# 3    tt0123134    tvMovie    Kismaszat és a Gézengúzok
# 4    tt0128154      movie                     Daybreak
# ..         ...        ...                          ...
# 143  tt9472276  tvEpisode                 The Shepherd
# 144  tt9506684  tvEpisode                 Episode #6.2
# 145  tt9728774   tvSeries           Innocent the Bhola
# 146  tt9758424  tvEpisode            Frozen and Afraid
# 147  tt9796264  tvEpisode                Alt for Noreg
#
#                    originalTitle  isAdult  startYear  endYear  runtimeMinutes  \
# 0              You Bet Your Life        0     1950.0   1961.0            30.0
# 1             The Traveling Poet        0     1993.0      NaN             8.0
# 2    The Ditchdigger's Daughters        0     1997.0      NaN            92.0
# 3      Kismaszat és a Gézengúzok        0     1984.0      NaN            74.0
# 4                       Daybreak        0     2002.0      NaN            87.0
# ..                           ...      ...        ...      ...             ...
# 143                 The Shepherd        0     2017.0      NaN            20.0
# 144                 Episode #6.2        0     2019.0      NaN            29.0
# 145           Innocent the Bhola        0     2020.0      NaN            98.0
# 146            Frozen and Afraid        0     2019.0      NaN            41.0
# 147                Alt for Noreg        0     2019.0      NaN            45.0
#
#                          genres
# 0       Comedy,Family,Game-Show
# 1                         Short
# 2               Biography,Drama
# 3       Adventure,Comedy,Family
# 4        Crime,Mystery,Thriller
# ..                          ...
# 143               Drama,History
# 144                      Comedy
# 145                    Thriller
# 146  Adventure,Game-Show,Horror
# 147                 Drama,Sport
#
# [148 rows x 9 columns]

# %% [markdown]
# #### Q8: Find all the titles that have an average rating lower than any title released in the year 2005.

# %%
pd.read_sql("""
    SELECT *
    FROM title_basics
    WHERE tconst IN (
        SELECT tconst
        FROM title_ratings
        WHERE averageRating < ANY (
            SELECT averageRating
            FROM title_ratings
            WHERE tconst IN (
                SELECT tconst
                FROM title_basics
                WHERE startYear = 2005
            )
        )
    )
""", conn)
# Out:
#         tconst  titleType                                   primaryTitle  \
# 0    tt0000912      short                    The Indian Runner's Romance
# 1    tt0017504      movie                                 Unseen Enemies
# 2    tt0024996      movie                               Coming Out Party
# 3    tt0029553      movie                            The Sheik Steps Out
# 4    tt0030476      short                              Music Made Simple
# ..         ...        ...                                            ...
# 214  tt9050522  tvEpisode  It's Okay for Me to Be Moe for Little Sisters
# 215  tt9452890  tvEpisode                           When Thieves Drop By
# 216  tt9642604      movie                        Los hombres sin rostros
# 217  tt9685774    tvMovie                             The Farewell Girls
# 218  tt9847426  tvEpisode                               All Star Games 4
#
#                                      originalTitle  isAdult  startYear  \
# 0                      The Indian Runner's Romance        0     1909.0
# 1                                   Unseen Enemies        0     1925.0
# 2                                 Coming Out Party        0     1934.0
# 3                              The Sheik Steps Out        0     1937.0
# 4                                Music Made Simple        0     1938.0
# ..                                             ...      ...        ...
# 214  It's Okay for Me to Be Moe for Little Sisters        0     2018.0
# 215                           When Thieves Drop By        0     2018.0
# 216                        Los hombres sin rostros        0     2016.0
# 217                             The Farewell Girls        0     2017.0
# 218                               All Star Games 4        0     2019.0
#
#      endYear  runtimeMinutes                      genres
# 0        NaN            11.0               Short,Western
# 1        NaN            54.0                     Western
# 2        NaN            80.0                       Drama
# 3        NaN            65.0                     Musical
# 4        NaN             8.0                Comedy,Short
# ..       ...             ...                         ...
# 214      NaN             NaN    Animation,Comedy,Romance
# 215      NaN             1.0  Action,Adventure,Animation
# 216      NaN            59.0                 Documentary
# 217      NaN            86.0                       Drama
# 218      NaN            30.0                   Game-Show
#
# [219 rows x 9 columns]

# %% [markdown]
# ### Correlated subqueries

# %% [markdown]
# #### Q9: Find the titles of movies that have a runtime longer than the average runtime of all movies in the same genre.

# %%
pd.read_sql("""
    SELECT primaryTitle, runtimeMinutes, genres
    FROM title_basics tb_outer
    WHERE titleType = 'movie'
    AND runtimeMinutes > (
        SELECT AVG(runtimeMinutes)
        FROM title_basics tb_inner
        WHERE tb_inner.genres = tb_outer.genres
        AND tb_inner.titleType = 'movie'
)
""", conn)
# Out:
#                                          primaryTitle  runtimeMinutes  \
# 0                                   Oath of Vengeance            57.0
# 1                  Escape from the Planet of the Apes            98.0
# 2                                           Per amore           100.0
# 3                      Trois pommes à côté du sommeil            98.0
# 4                                      Saajan Ka Ghar           153.0
# 5                                       L'île d'amour           106.0
# 6           Proêzas de Satanás na Vila de Leva-e-Traz           100.0
# 7                                   An Outgoing Woman           118.0
# 8                                      Mask of Desire           105.0
# 9                             A Little Bit of Freedom           102.0
# 10                                  Budapest Retro 2.            90.0
# 11                                        Narrowsburg            84.0
# 12                                      Tandoori Love           100.0
# 13                                          Cock Tail           132.0
# 14                                              Dream           126.0
# 15                                                 MW           129.0
# 16                           LAID: Life as It's Dealt           105.0
# 17                    Footloose: A Story of Belonging            93.0
# 18                       Chowrasta Crossroads of Love           120.0
# 19                                      Ride the Wave            84.0
# 20                                            Kakraki           105.0
# 21                                             Shatru           150.0
# 22                                   Great Depression           120.0
# 23                                     Die Vermittler            73.0
# 24                                  The Mountain Path            93.0
# 25                                        50 Horizons            77.0
# 26                                             Deluxe            58.0
# 27  Dad and I - Chapter 1: The Life of Timothy J. ...           111.0
# 28                                         Tai Hong 2           109.0
# 29                               This is Söderstadion            82.0
# 30                                            Le Ride            90.0
# 31                                Manam Kothi Paravai           137.0
# 32                                     Mastorna Blues            80.0
# 33                                         Perception           102.0
# 34                                    Natha Pure Aata           139.0
# 35                                      Ordinary Gods           107.0
# 36                                              Arest           126.0
#
#                            genres
# 0                         Western
# 1                   Action,Sci-Fi
# 2                   Drama,Romance
# 3                           Drama
# 4                           Drama
# 5                   Drama,Romance
# 6                          Comedy
# 7                           Drama
# 8                           Drama
# 9                           Drama
# 10                    Documentary
# 11                    Documentary
# 12           Comedy,Drama,Romance
# 13                         Comedy
# 14                       Thriller
# 15                 Drama,Thriller
# 16                  Drama,Romance
# 17                    Documentary
# 18                          Drama
# 19                    Documentary
# 20                   Comedy,Drama
# 21             Action,Crime,Drama
# 22                          Drama
# 23                    Documentary
# 24                    Documentary
# 25                    Documentary
# 26                          Music
# 27                      Biography
# 28                         Horror
# 29                    Documentary
# 30  Biography,Documentary,History
# 31                 Comedy,Romance
# 32                    Documentary
# 33                       Thriller
# 34                         Comedy
# 35    Biography,Documentary,Drama
# 36                          Drama

# %% [markdown]
# ### JOINs

# %% [markdown]
# ### `JOIN` aka `INNER JOIN`

# %% [markdown]
# #### Q10: Find all movies and their corresponding ratings.

# %%
pd.read_sql("""
    SELECT * FROM title_basics
    WHERE titleType = "movie"
""", conn)
# Out:
#         tconst titleType                    primaryTitle  \
# 0    tt0016344     movie             Shirayuri wa nageku
# 1    tt0017504     movie                  Unseen Enemies
# 2    tt0024996     movie                Coming Out Party
# 3    tt0029553     movie             The Sheik Steps Out
# 4    tt0035860     movie              The Fallen Sparrow
# ..         ...       ...                             ...
# 183  tt8787458     movie                            Gado
# 184  tt8906732     movie  A Song or Two to Make You Feel
# 185  tt9198442     movie                My Hero Academia
# 186  tt9642604     movie         Los hombres sin rostros
# 187  tt9653828     movie                           Arest
#
#                       originalTitle  isAdult  startYear endYear  \
# 0               Shirayuri wa nageku        0     1925.0    None
# 1                    Unseen Enemies        0     1925.0    None
# 2                  Coming Out Party        0     1934.0    None
# 3               The Sheik Steps Out        0     1937.0    None
# 4                The Fallen Sparrow        0     1943.0    None
# ..                              ...      ...        ...     ...
# 183                            Gado        0        NaN    None
# 184  A Song or Two to Make You Feel        0     2018.0    None
# 185                My Hero Academia        0        NaN    None
# 186         Los hombres sin rostros        0     2016.0    None
# 187                           Arest        0     2019.0    None
#
#      runtimeMinutes                      genres
# 0               NaN                        None
# 1              54.0                     Western
# 2              80.0                       Drama
# 3              65.0                     Musical
# 4              94.0           Film-Noir,Mystery
# ..              ...                         ...
# 183             NaN                     Western
# 184            54.0                       Music
# 185             NaN  Action,Adventure,Animation
# 186            59.0                 Documentary
# 187           126.0                       Drama
#
# [188 rows x 9 columns]

# %%
pd.read_sql("""
    SELECT * FROM title_ratings
""", conn)
# Out:
#         tconst  averageRating  numVotes
# 0    tt0000912            4.3        73
# 1    tt0017504            4.8        27
# 2    tt0024996            5.9        66
# 3    tt0029553            6.0        45
# 4    tt0030476            6.2        81
# ..         ...            ...       ...
# 384  tt9728774            8.9        11
# 385  tt9758424            8.3        58
# 386  tt9796264            7.7        53
# 387  tt9847426            7.3         8
# 388  tt9854186            7.4        22
#
# [389 rows x 3 columns]

# %%
pd.read_sql("""
    SELECT b.primaryTitle, r.averageRating
    FROM title_basics b
    JOIN title_ratings r ON b.tconst = r.tconst
    WHERE b.titleType = 'movie'
""", conn)
# Out:
#                                   primaryTitle  averageRating
# 0                               Unseen Enemies            4.8
# 1                             Coming Out Party            5.9
# 2                          The Sheik Steps Out            6.0
# 3                           The Fallen Sparrow            6.6
# 4                            Oath of Vengeance            5.7
# ..                                         ...            ...
# 90  Horror, Madness & Mayhem Vol 1 Snuff Party            7.2
# 91                             Natha Pure Aata            4.9
# 92                               Ordinary Gods            8.5
# 93                     Los hombres sin rostros            6.8
# 94                                       Arest            7.4
#
# [95 rows x 2 columns]

# %% [markdown]
# ### `LEFT JOIN` aka `LEFT OUTER JOIN`

# %% [markdown]
# #### Q11: Find all movies and their corresponding ratings. If a movie doesn't have a rating, still include it in the results.

# %%
pd.read_sql("""
    SELECT * FROM title_basics
    WHERE titleType = "movie"
""", conn)
# Out:
#         tconst titleType                    primaryTitle  \
# 0    tt0016344     movie             Shirayuri wa nageku
# 1    tt0017504     movie                  Unseen Enemies
# 2    tt0024996     movie                Coming Out Party
# 3    tt0029553     movie             The Sheik Steps Out
# 4    tt0035860     movie              The Fallen Sparrow
# ..         ...       ...                             ...
# 183  tt8787458     movie                            Gado
# 184  tt8906732     movie  A Song or Two to Make You Feel
# 185  tt9198442     movie                My Hero Academia
# 186  tt9642604     movie         Los hombres sin rostros
# 187  tt9653828     movie                           Arest
#
#                       originalTitle  isAdult  startYear endYear  \
# 0               Shirayuri wa nageku        0     1925.0    None
# 1                    Unseen Enemies        0     1925.0    None
# 2                  Coming Out Party        0     1934.0    None
# 3               The Sheik Steps Out        0     1937.0    None
# 4                The Fallen Sparrow        0     1943.0    None
# ..                              ...      ...        ...     ...
# 183                            Gado        0        NaN    None
# 184  A Song or Two to Make You Feel        0     2018.0    None
# 185                My Hero Academia        0        NaN    None
# 186         Los hombres sin rostros        0     2016.0    None
# 187                           Arest        0     2019.0    None
#
#      runtimeMinutes                      genres
# 0               NaN                        None
# 1              54.0                     Western
# 2              80.0                       Drama
# 3              65.0                     Musical
# 4              94.0           Film-Noir,Mystery
# ..              ...                         ...
# 183             NaN                     Western
# 184            54.0                       Music
# 185             NaN  Action,Adventure,Animation
# 186            59.0                 Documentary
# 187           126.0                       Drama
#
# [188 rows x 9 columns]

# %%
pd.read_sql("""
    SELECT * FROM title_ratings
""", conn)
# Out:
#         tconst  averageRating  numVotes
# 0    tt0000912            4.3        73
# 1    tt0017504            4.8        27
# 2    tt0024996            5.9        66
# 3    tt0029553            6.0        45
# 4    tt0030476            6.2        81
# ..         ...            ...       ...
# 384  tt9728774            8.9        11
# 385  tt9758424            8.3        58
# 386  tt9796264            7.7        53
# 387  tt9847426            7.3         8
# 388  tt9854186            7.4        22
#
# [389 rows x 3 columns]

# %%
pd.read_sql("""
    SELECT b.primaryTitle, r.averageRating
    FROM title_basics b
    LEFT JOIN title_ratings r ON b.tconst = r.tconst
    WHERE b.titleType = 'movie'
""", conn)
# Out:
#                        primaryTitle  averageRating
# 0               Shirayuri wa nageku            NaN
# 1                    Unseen Enemies            4.8
# 2                  Coming Out Party            5.9
# 3               The Sheik Steps Out            6.0
# 4                The Fallen Sparrow            6.6
# ..                              ...            ...
# 183                            Gado            NaN
# 184  A Song or Two to Make You Feel            NaN
# 185                My Hero Academia            NaN
# 186         Los hombres sin rostros            6.8
# 187                           Arest            7.4
#
# [188 rows x 2 columns]

# %% [markdown]
# ### `RIGHT JOIN` aka `RIGHT OUTER JOIN`

# %% [markdown]
# #### Q13: Solve Q12 using `RIGHT JOIN`.

# %%
pd.read_sql("""
    SELECT b.primaryTitle, r.averageRating
    FROM title_ratings r 
    RIGHT JOIN title_basics b ON b.tconst = r.tconst
    WHERE b.titleType = 'movie'
""", conn)
# Out:
#                        primaryTitle  averageRating
# 0               Shirayuri wa nageku            NaN
# 1                    Unseen Enemies            4.8
# 2                  Coming Out Party            5.9
# 3               The Sheik Steps Out            6.0
# 4                The Fallen Sparrow            6.6
# ..                              ...            ...
# 183                            Gado            NaN
# 184  A Song or Two to Make You Feel            NaN
# 185                My Hero Academia            NaN
# 186         Los hombres sin rostros            6.8
# 187                           Arest            7.4
#
# [188 rows x 2 columns]

# %% [markdown]
# #### Q14: Find all movies, their average rating, and the total number of regions they have been released in.

# %%
pd.read_sql("""
SELECT b.primaryTitle, r.averageRating, COUNT(DISTINCT a.region) AS totalRegions
FROM title_basics b
JOIN title_ratings r ON b.tconst = r.tconst
JOIN title_akas a ON b.tconst = a.titleId
WHERE b.titleType = 'movie'
GROUP BY b.primaryTitle, b.tconst, r.averageRating
ORDER BY totalRegions DESC, averageRating DESC, primaryTitle ASC
""", conn)
# Out:
#                           primaryTitle  averageRating  totalRegions
# 0                                 Wild            7.1            50
# 1                  Return of the Seven            5.5            40
# 2   Escape from the Planet of the Apes            6.3            38
# 3                         Crazed Fruit            7.2            18
# 4                   The Fallen Sparrow            6.6            17
# ..                                 ...            ...           ...
# 90                          Fondovalle            4.6             1
# 91              Klarar Bananen Biffen?            4.6             1
# 92                      Saajan Ka Ghar            4.3             1
# 93                           Cock Tail            4.1             1
# 94                                Adhu            3.6             1
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Order of execution
#
# Execution order: `FROM`, `JOIN`, `WHERE`, `GROUP BY`, `HAVING`, `ORDER BY`, and `LIMIT`.

# %% [markdown]
# ### Window functions aka Analytic Functions aka Online Analytical Processing (OLAP) functions
#
# - What are window functions?
#     - Special types of functions that perform calculations across a set of table rows that are related to the current row.
#     - Unlike aggregate functions, window functions do not collapse the result set into a single row or group of rows. Instead, they provide a result for each row while still considering a "window" of other rows.
#
# ### Clauses
#
# - `OVER`: defines the window or partition over which the function operates.
# - `ORDER BY`: Specifies the order in which rows should be processed within each window.
# - `PARTITION BY`: divides the result set into partitions to apply the function to each partition separately.
#
# ### Ranking functions
#
# - `RANK`
#     - returns same ranking in case of a tie, with gaps in the rankings
#     - why are there gaps? because rank assigned after a tie skips over the subsequent positions, resulting in a gap
# - `DENSE_RANK`:
#     - returns the same ranking as `RANK` with no gaps in the rankings
# - `ROW_NUMBER`:
#     - returns unique number for each row with rankings arbitrarily assigned in case of a tie
#     - ordering requirements can help you break ties and come up with predictable numbering

# %% [markdown]
# #### Q15: Rank all titlesIDs by their rating (descending order).

# %%
pd.read_sql("""
    SELECT 
        tconst, averageRating, 
        RANK() OVER (ORDER BY averageRating DESC) AS titleRank
    FROM title_ratings
""", conn)
# Out:
#          tconst  averageRating  titleRank
# 0     tt2924058           10.0          1
# 1     tt1841655            9.8          2
# 2    tt12601448            9.6          3
# 3     tt4065164            9.5          4
# 4     tt4740328            9.5          4
# ..          ...            ...        ...
# 384   tt5188300            3.2        383
# 385  tt18257696            2.9        386
# 386   tt6840238            2.8        387
# 387   tt0933342            2.7        388
# 388   tt4175544            1.0        389
#
# [389 rows x 3 columns]

# %% [markdown]
# #### Q16: Rank all titles by their rating (descending order).

# %%
pd.read_sql("""
    SELECT 
        b.tconst, b.primaryTitle, 
        r.averageRating, 
        RANK() OVER (ORDER BY r.averageRating DESC) AS titleRank
    FROM title_ratings r
    JOIN title_basics b ON r.tconst = b.tconst
    LIMIT 15
""", conn)
# Out:
#         tconst           primaryTitle  averageRating  titleRank
# 0    tt2924058           Episode #9.2           10.0          1
# 1    tt1841655             In the Bin            9.8          2
# 2   tt12601448             Episode 11            9.6          3
# 3    tt4065164           All Shook Up            9.5          4
# 4    tt4740328   Lavanya fires Khushi            9.5          4
# 5    tt7385060  A Premature Christmas            9.5          4
# 6    tt2271562           Episode #1.6            9.4          7
# 7   tt23901758      The Mountain Path            9.4          7
# 8   tt29208392               Postmord            9.3          9
# 9   tt30835366       Learning English            9.3          9
# 10   tt0698358               La bicha            9.2         11
# 11  tt13677184        Feliz Ano Novo!            9.2         11
# 12  tt27749874  Shoeless in the Woods            9.2         11
# 13   tt5316184           Episode #1.9            9.2         11
# 14  tt18339386             2nd Chance            9.1         15

# %% [markdown]
# #### Q17: Dense rank all titles by their rating (descending order).

# %%
pd.read_sql("""
    SELECT 
        b.tconst, b.primaryTitle, 
        r.averageRating, 
        DENSE_RANK() OVER (ORDER BY r.averageRating DESC) AS titleDenseRank
    FROM title_ratings r
    JOIN title_basics b ON r.tconst = b.tconst
    LIMIT 15
""", conn)
# Out:
#         tconst           primaryTitle  averageRating  titleDenseRank
# 0    tt2924058           Episode #9.2           10.0               1
# 1    tt1841655             In the Bin            9.8               2
# 2   tt12601448             Episode 11            9.6               3
# 3    tt4065164           All Shook Up            9.5               4
# 4    tt4740328   Lavanya fires Khushi            9.5               4
# 5    tt7385060  A Premature Christmas            9.5               4
# 6    tt2271562           Episode #1.6            9.4               5
# 7   tt23901758      The Mountain Path            9.4               5
# 8   tt29208392               Postmord            9.3               6
# 9   tt30835366       Learning English            9.3               6
# 10   tt0698358               La bicha            9.2               7
# 11  tt13677184        Feliz Ano Novo!            9.2               7
# 12  tt27749874  Shoeless in the Woods            9.2               7
# 13   tt5316184           Episode #1.9            9.2               7
# 14  tt18339386             2nd Chance            9.1               8

# %% [markdown]
# #### Q18: Assign a sequential rank to each title by rating (descending order). If there are ties in ratings, break ties based on ascending order of titles.

# %%
pd.read_sql("""
    SELECT 
        b.tconst, b.primaryTitle, 
        r.averageRating, 
        ROW_NUMBER() OVER (ORDER BY r.averageRating DESC, primaryTitle ASC) AS titleUniqueRank
    FROM title_ratings r
    JOIN title_basics b ON r.tconst = b.tconst
    LIMIT 15
""", conn)
# Out:
#         tconst           primaryTitle  averageRating  titleUniqueRank
# 0    tt2924058           Episode #9.2           10.0                1
# 1    tt1841655             In the Bin            9.8                2
# 2   tt12601448             Episode 11            9.6                3
# 3    tt7385060  A Premature Christmas            9.5                4
# 4    tt4065164           All Shook Up            9.5                5
# 5    tt4740328   Lavanya fires Khushi            9.5                6
# 6    tt2271562           Episode #1.6            9.4                7
# 7   tt23901758      The Mountain Path            9.4                8
# 8   tt30835366       Learning English            9.3                9
# 9   tt29208392               Postmord            9.3               10
# 10   tt5316184           Episode #1.9            9.2               11
# 11  tt13677184        Feliz Ano Novo!            9.2               12
# 12   tt0698358               La bicha            9.2               13
# 13  tt27749874  Shoeless in the Woods            9.2               14
# 14  tt18339386             2nd Chance            9.1               15

# %% [markdown]
# ### Ranking using `PARTITION BY`

# %% [markdown]
# #### Q19: Rank all titles by their rating (descending order) within each genre.

# %%
pd.read_sql("""
    SELECT 
        b.tconst, b.primaryTitle, b.genres,r.averageRating, 
        ROW_NUMBER() OVER (PARTITION BY b.genres ORDER BY r.averageRating DESC) AS genreRanking
    FROM title_ratings r
    JOIN title_basics b ON r.tconst = b.tconst
    WHERE b.genres IS NOT NULL
""", conn)
# Out:
#          tconst                             primaryTitle   genres  \
# 0     tt5316184                             Episode #1.9   Action
# 1    tt27946257  Yongchun of South Shaolin: Breakthrough   Action
# 2    tt28114581                          Tebus the Movie   Action
# 3     tt0892322                               Lumines II   Action
# 4     tt0318498              Ninja in the Killing Fields   Action
# ..          ...                                      ...      ...
# 380   tt0556591                               Death Ride  Western
# 381   tt0631931                  Truth About Gunfighting  Western
# 382   tt0038874                      Red River Renegades  Western
# 383   tt0037142                        Oath of Vengeance  Western
# 384   tt0017504                           Unseen Enemies  Western
#
#      averageRating  genreRanking
# 0              9.2             1
# 1              8.1             2
# 2              7.4             3
# 3              7.3             4
# 4              3.8             5
# ..             ...           ...
# 380            8.6             1
# 381            7.6             2
# 382            6.6             3
# 383            5.7             4
# 384            4.8             5
#
# [385 rows x 5 columns]

# %% [markdown]
# ### Aggregate functions with window functions
#
# `SUM`, `AVG`, `COUNT`, `MIN`, `MAX`

# %% [markdown]
# #### Q20: Rank all titles by total number of ratings (descending order) for each title. If there are ties in ratings, break ties based on ascending order of titles.

# %%
pd.read_sql("""
    SELECT 
        b.tconst, b.primaryTitle, 
        SUM(r.numVotes) AS totalRatings,
        RANK() OVER (ORDER BY SUM(r.numVotes) DESC, primaryTitle ASC) AS rating_rank
    FROM title_basics b
    JOIN title_ratings r ON b.tconst = r.tconst
    GROUP BY b.tconst, b.primaryTitle
""", conn)
# Out:
#          tconst                        primaryTitle  totalRatings  rating_rank
# 0     tt2305051                                Wild      140750.0            1
# 1     tt0067065  Escape from the Planet of the Apes       41883.0            2
# 2    tt13659418                         Pam & Tommy       40732.0            3
# 3     tt6294706                             The Chi        8463.0            4
# 4     tt0060897                 Return of the Seven        4931.0            5
# ..          ...                                 ...           ...          ...
# 384   tt4175544                      Reem Halloween           5.0          385
# 385  tt27749874               Shoeless in the Woods           5.0          386
# 386  tt23901758                   The Mountain Path           5.0          387
# 387   tt4041376                 Vampires & Hormones           5.0          388
# 388   tt5976978                        White Flight           5.0          389
#
# [389 rows x 4 columns]
